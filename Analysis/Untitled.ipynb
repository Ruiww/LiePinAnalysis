# %%
import pandas as pd
csvfile = pd.read_csv('data.csv')
df = pd.DataFrame(csvfile)
print(df)
# Out:
#                                             JobTitle              company  \
# 0                                               数据统计       衡阳苹果装饰设计工程有限公司
# 1                                            数据分析工程师                  普迪飞
# 2                                            数据分析工程师                 海云数据
# 3                                             数据分析专员                 大唐财富
# 4                                             营销中心助理         广州正雄装饰设计有限公司
# 5                                            采购专员(B)                  英业达
# 6                                             数据分析专员                   聚美
# 7                                         数据分析专员（逾期）                 华夏信财
# 8                                               副总秘书               浩丰规划设计
# 9                                            高级售后工程师                  卓因达
# 10                                           风控数据分析岗         北京星河金服科技有限公司
# 11                                           数据分析工程师                沐金农科技
# ...
